# %% [markdown]
# # Categorical Classification Loss
#
# ## Example
# ![image.png](attachment:3ccabe8f-27a4-40b8-af70-4524a17c1c7a.png)

# %% [markdown]
# ## Loss Functions
# ### Classification Error
# ![image.png](attachment:fb23905c-0ee5-4062-b680-ccf87d9a1b90.png)

# %% [markdown]
# ### Mean Squared Error (MSE)
# ![image.png](attachment:43194b54-d8d5-4d68-b72e-bb3b559e28e0.png)

# %% [markdown]
# ### Cross Entropy Loss
# ![image.png](attachment:2cbadd2c-ba4a-4a0a-a2ae-eacc60191138.png)

# %% [markdown]
# #### Implement in Python
# ![image.png](attachment:1770f745-5631-4ac2-9041-c0ecc5c263fe.png)
