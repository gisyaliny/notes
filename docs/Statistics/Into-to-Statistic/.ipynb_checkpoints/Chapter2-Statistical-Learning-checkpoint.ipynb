# %% [markdown]
# ## Prediction and Inference
# ### Prediction
# * The accuracy of predictions depend on two quantities, reducible error and irreducible error
#     - Reducible Error (Residual)
#     - Irreducible Error (Noise)
# ![image.png](attachment:e95ed092-43b6-43cf-bc3f-785d5530be9d.png)

# %% [markdown]
# ### Inference
# - Understand the exact form of f(x)

# %% [markdown]
# ### How to estimate f
# #### Parametric Methods
# - Make a assumption about the function form
# - Train the model
# - **Disadvantage**: the model we choose not match the true unknown form of f

# %% [markdown]
# #### Non-Parametric Methods
# * **Disadvantage**: requires large number of observations
#
# #### Trade-off between Prediction Accuracy and Model Interpretability
# - If we are mainly interested in **inference**, then restrictive models are much more **interpretable**. For instance, when inference is the goal, the linear model may be a good choice
# ![image.png](attachment:70d969a5-a8b1-4abd-a060-cd62f0406cc3.png)

# %% [markdown]
# ### Supervised Versus Unsupervised Learning
# #### Supervised Learning
# * Analysis the relationship between independent variables (x_1,x_2,…)and response (y)
#     - Regression
#
# #### Unsupervised Learning
# * Understand the relationships between the variables or between the observations
#     - Cluster analysis
#
# ### Regression Versus Classification Problems
# #### Regression
# - Problems with a quantitative response as regression problems
# #### Classification
# - Problems with a qualitative response as classification problems

# %% [markdown]
# ### The Bias-Variance Trade-Off
# ![image.png](attachment:148e1f56-7a84-419a-aa12-b3f9d442d1e0.png)

# %% [markdown]
# ### Accuracy Measuring
# #### Classification
#     * Instead of  using MSE, the most common approach for quantifying the accuracy is error rate
#         * $\frac{1}{n}\sum_{i=1}^{n}I(y_i\neq \haty_i)$
