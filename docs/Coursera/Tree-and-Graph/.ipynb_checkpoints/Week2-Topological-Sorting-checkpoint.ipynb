# %% [markdown]
# ## Topological-Sorting
# ### Definition
# ![image.png](attachment:0077920f-e4b3-413d-9394-2952d83778b9.png)

# %% [markdown]
# ### How to find it
# ![image.png](attachment:00cc30ea-5d12-4159-aced-8df28ec55fce.png)

# %% [markdown]
# ## Strongly-Connected-Components
# ### Definition
# ![image.png](attachment:72789e31-10b1-4224-aeea-924607fc6e15.png)

# %% [markdown]
# - Quiz
# ![image.png](attachment:4ff36d59-9179-4dda-86a1-ed2e47fc6756.png)

# %% [markdown]
# ### Properties of MSCC
# ![image.png](attachment:3acb9ebd-cddd-4d7b-b900-f73f8ab84d67.png)

# %% [markdown]
# ### How to find MSCC
# ![image.png](attachment:922293ec-56a5-481e-8c85-d27e5277508d.png)
