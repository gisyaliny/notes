# %% [markdown]
# ## Basic Statistical Graphs
# ### Univariate Distribution
# ![image.png](attachment:95c19a7f-aeeb-4f42-8cb3-cf47a1800b1e.png)

# %% [markdown]
# ### Bivariate Distribution
# ![image.png](attachment:ecd4a40e-f0d1-4a24-968f-aca16b2c8519.png)

# %% [markdown]
# ## Spatial Heterogeneity
# ![image.png](attachment:d4335a24-2c54-41da-a73a-bd17972f82b8.png)

# %% [markdown]
# ## Tools for Spatial Heterogeneity Analysis (Bivariate)
# ### Averages Chart
#
# ![image.png](attachment:519edda7-9a29-49df-af85-a585551a74ab.png)

# %% [markdown]
# ### Brushing the Scatter Plot
# ![image.png](attachment:4a70079a-b4ec-4fa8-a53b-4d47178bd175.png)

# %% [markdown]
# ## Multivariate EDA
# ### Objective
# ![image.png](attachment:303bfbf9-2290-478a-8cf8-ddecf901e305.png)

# %% [markdown]
# ## Methods for multivariate EDA
# ### Bubble Chart
# ![image.png](attachment:86817a68-9d79-4ca5-870d-73d70ff3bc6a.png)

# %% [markdown]
# ### 3D Scatter Plot
# ![image.png](attachment:5b3068a8-344a-478d-a351-a0b7f8926779.png)

# %% [markdown]
# ### Parallel coordinate plot(PCP)
# ![image.png](attachment:9bc85a79-3526-4165-9adc-46588c09517b.png)

# %% [markdown]
# ### Conditional Plots
# ![image.png](attachment:3a25f1f0-59f3-4b4b-ba74-6f7c65dd4563.png)
