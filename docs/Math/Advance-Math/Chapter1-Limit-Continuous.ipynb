# %% [markdown]
# ## Limit
# ### Domain of functions
# ![image.png](attachment:eaef4416-76fd-47b0-9f62-40c2ecbf1308.png)!

# %% [markdown]
# ### The equivalent of functions
# ![image.png](attachment:18020e2a-46d8-4065-9cf6-e79a370a77db.png)

# %% [markdown]
# ### The definition of limit
# ![image.png](attachment:8c7750bc-9728-4fd6-9c7b-8e3e2b9ddba4.png)

# %% [markdown]
# ### Solve the limit Problem
# #### Substitute Directly
# #### L'Hopital's Law
# ![image.png](attachment:e3cf3e18-b53e-4fb3-85a7-1fa77aa4b328.png)

# %% [markdown]
# #### The Property of infinity (∞) and infinity small (0)
# ![image.png](attachment:d941f7fa-ca50-4674-aeab-4e72842082b9.png)

# %% [markdown]
# #### Three special cases
# * Factorization
# ![image.png](attachment:0b6282c7-b4a0-41d3-b698-17766777dfa6.png)

# %% [markdown]
# * Rationalization of numerator and denominator
# ![image.png](attachment:f1aa2b1c-6f99-47a4-b57f-807a004dc446.png)

# %% [markdown]
# * Get the highest order ($x\to \infty$)
# ![image.png](attachment:edaaa6ad-ed70-474f-b18a-c3b514925bf6.png)

# %% [markdown]
# * Two important limit
# ⁡![image.png](attachment:edf55679-a584-457e-a81c-5375da0b0bbc.png)

# %% [markdown]
# * Equivalence of infinity small
# ![image.png](attachment:7ddcd752-f3ef-4cc7-80f5-e498a2da710b.png)

# %% [markdown]
# ## Continuous
# ### Continuous in functions
# ⁡![image.png](attachment:e7944414-b344-40d0-a104-aa12b362bf20.png)

# %% [markdown]
# ### Example
# ![image.png](attachment:5dedbc1a-56ad-45b9-8eab-056908c7e8c3.png)

# %% [markdown]
# ### The break points of functions
# ![image.png](attachment:5d3b54cc-414a-4317-9402-ba8b5ab64743.png)

# %% [markdown]
# ### The Intermediate Value Theorem
# ![image.png](attachment:dce9da14-8e99-42b4-9cff-ec0efa0088e6.png)
