# %% [markdown]
# ## Matrix Mutiplication
# - ![image.png](attachment:image.png)

# %% [markdown]
# ### Interpret by column
# - We could consider it as A * a set of column vectors, since each column of C only depends on A * each column of B
#
# - For example
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Interpret by row
# - Rows of C are combination of rows of B
#
# - For example
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Another mutiplication rule
# - $Z$ = Column of $A$ * Row of $B$
# - Example
# ![image.png](attachment:image.png)
#
# - ![image.png](attachment:76b13ff1-bd98-4db8-b631-d3eb09b5b88a.png)

# %% [markdown]
# ## Block multiplication

# %% [markdown]
# ![image.png](attachment:3b087179-133c-49c8-b453-70af03c3b34e.png)

# %% [markdown]
# ## Inverse
# ![image.png](attachment:085cbd8e-48ce-44ce-a270-7a954e24893a.png)
# ### Example
# ![image.png](attachment:bd2ca119-e38f-491b-897e-8e2e979a5215.png)

# %% [markdown]
# ### Two ways to solve the inverse
# #### Solve them by the meaning
# ![image.png](attachment:c007775c-fb16-45a5-b13e-52761f8e2942.png)
# #### Gauss -Jordan (Augmented matrix)
# ![image.png](attachment:4e9e3c3d-6424-4e39-bdd1-7dbdc727704e.png)

# %% [markdown]
# ## Singular matrix (do not have inverse)
# ![image.png](attachment:6205cb75-68de-420e-b3d2-556768b5698a.png)

# %% [markdown]
# ## Gauss-Jordan function to get inverse (solve two eqs at once)
# ![image.png](attachment:4b2b3603-d8b6-4080-89b5-ddbe00ec9464.png)
