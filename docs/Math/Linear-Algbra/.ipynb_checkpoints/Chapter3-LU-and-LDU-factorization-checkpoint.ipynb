# %% [markdown]
# # $LU and LDU factorization$
# ## Product of elimination matrices
# ![image.png](attachment:37f59a7c-37cb-41c1-a6d1-3a8357c99693.png)

# %% [markdown]
# ## Decompose Matrices
# ### $LU$ factorization
#
# ![image.png](attachment:f771808a-6283-45a7-8373-511c704e7741.png)
# ![image.png](attachment:43fcb5d9-98ec-46aa-b1ae-4efd63b71530.png)

# %% [markdown]
# ### (Personal Question) Why we want $LU$ decomposition
