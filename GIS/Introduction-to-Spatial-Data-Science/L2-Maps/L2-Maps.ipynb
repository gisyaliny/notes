# %% [markdown]
# ## Map
# ![image.png](attachment:22cc3e01-fd66-487b-86d7-93f18bedd872.png)

# %% [markdown]
# ### Traditional Knowledge Discovery
# ![image.png](attachment:acbf0e9e-ab1c-4a00-9ba4-57c465014bed.png)

# %% [markdown]
# ## Map Design Primer
# ### How to Lie with Maps
# ![image.png](attachment:b9214408-b7bd-45b2-b473-a7ecd637c5de.png)

# %% [markdown]
# ### Natural Breaks and Quantile
# ![image.png](attachment:d7bcf6d3-b343-4b1a-a891-536d01b3441f.png)

# %% [markdown]
# ## Continuous Statistical Maps
# ### Percentile Map
# ![image.png](attachment:941875c0-3414-4c4d-97a7-ab1b62431cc0.png)

# %% [markdown]
# ### Box map plot
# ![image.png](attachment:fc07fc4d-ce39-43be-8148-67de248461a8.png)

# %% [markdown]
# ### Standard Deviation Map
# ![image.png](attachment:ecbdb7ed-5204-4114-b50e-8da02c69376d.png)

# %% [markdown]
# ## Categorial Statistical Maps
# ### Co-Location Map
# ![image.png](attachment:cde91a81-688d-4cc6-addb-854e57b17abc.png)

# %% [markdown]
# ### Cartogram
# ![image.png](attachment:a5f2e47a-0cbe-4a70-a68d-6d93f353ad0d.png)

# %% [markdown]
# ### Conditional Map
# ![image.png](attachment:164e55c2-309c-47f3-b63b-40347ad0ceef.png)
