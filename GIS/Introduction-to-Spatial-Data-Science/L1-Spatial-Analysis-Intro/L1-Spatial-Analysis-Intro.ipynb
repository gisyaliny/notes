# %% [markdown]
# ## What's spatial analysis
# ![image.png](attachment:d95b4ba7-3e4e-47d8-8c15-d649c329eeb6.png)

# %% [markdown]
# ### What's "geospatial"
# ![image.png](attachment:ad4bff7e-093d-471c-9358-03ab727d7e08.png)

# %% [markdown]
# ### Components (workflow) of spatial data analysis
# ![image.png](attachment:424effae-80d3-4829-bb38-211adccf6390.png)

# %% [markdown]
# ## What's Spatial Questions
#
# ![image.png](attachment:42cf4e5f-ad2e-4da5-a354-1dba53f87be5.png)

# %% [markdown]
# ## Spatial data types
# ![image.png](attachment:bc1e22f4-2f65-4c01-b69e-3e6658fc4d8d.png)
#
# ### Point
# ![image.png](attachment:ff3279c7-c6ca-4cd1-b096-5f5d3249a77a.png)

# %% [markdown]
# ### Surface
# ![image.png](attachment:0fda3f83-3500-46ae-a2e9-a2a1934cd6ec.png)

# %% [markdown]
# ### Discrete spatial data - lattice data
# ![image.png](attachment:641e0fd4-61f8-407d-b08b-e2a826ad2f56.png)

# %% [markdown]
# ### Network

# %% [markdown]
# ## Modifiable Areal Unit Problem (MAUP)
# ![image.png](attachment:20037875-509f-4223-bc0c-18e9dff58ff7.png)

# %% [markdown]
# ## Change of Support Problem
# ![image.png](attachment:165b4ea8-3e9a-4bef-9ed6-453e05e97b14.png)
