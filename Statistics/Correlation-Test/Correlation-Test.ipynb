# %% [markdown]
# # Correlation test

# %% [markdown]
# ## Pearson Correlation test
# ### Definition and purpose
# Measures the strength and direction of a linear association between two variables. It defines as
#
# ![image.png](attachment:84aca863-1bae-4a4f-a749-d1fd5486f040.png)

# %% [markdown]
# ### Geometric Interpretation
# ![image.png](attachment:6943473c-265d-4cda-8a9f-e86361244521.png)

# %% [markdown]
# ## Spearman Correlation Test
# ### Definition and Purpose
# ![image.png](attachment:e47f7ed3-3240-462a-8d47-44c60656da25.png)

# %% [markdown]
# ### Assumption
# ![image.png](attachment:2006d116-9429-4a15-9ce9-851c1da06394.png)

# %% [markdown]
# ## Kendall rank correlation coefficient
# ### Definition
# ![image.png](attachment:89621566-5dd4-461e-a5eb-262bfa1cd096.png)

# %% [markdown]
# ### Determining significance
# ![image.png](attachment:465e637e-a0de-4419-a113-68b6a1d9d74d.png)

# %% [markdown]
# ### Example
# ![image.png](attachment:692b1a45-5ba8-4d73-91a5-3d2d98448d1d.png)

# %% [markdown]
# ### Comparison
# ![image.png](attachment:78f4c329-1ccd-4f10-9628-352b1a8cfde7.png)

# %% [markdown]
# # Significance Checking
# ## Permutation Test
# ![image.png](attachment:260f4713-2703-441a-9377-aea2c5a2f928.png)

# %% [markdown]
# ## Fisher Transformation (Fisher Z-transformation)
# ![image.png](attachment:7a5f7027-75e0-4684-a6c2-997f52aff316.png)

# %% [markdown]
# ### Definition
# ![image.png](attachment:81c6592b-a55c-4fc4-aa66-76c9d5024619.png)

# %% [markdown]
# ### Examples
# ![image.png](attachment:1c388bce-be9a-40da-b73e-e8e700856e4d.png)

# %% [markdown]
# ### Comparison

# %% [markdown]
# ![image.png](attachment:5c447633-8c14-4ac8-80f5-96667b69600a.png)
