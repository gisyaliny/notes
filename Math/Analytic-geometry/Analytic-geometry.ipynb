# %% [markdown]
# ## 5 equation forms of lines
# ### Slope intercept form
# ![image.png](attachment:6d06b6ce-6f71-4711-b785-429a6f3056ae.png)

# %% [markdown]
# ### Point slope form
# ![image.png](attachment:80fd42de-bf27-4c42-8412-e697e3c3161c.png)

# %% [markdown]
# ### Point-Point Form
# ![image.png](attachment:28f815d5-de90-4705-9ede-ae4c405fe163.png)

# %% [markdown]
# ### Intercept Form
# ![image.png](attachment:899e8109-db52-45b3-ae44-6390101abc14.png)

# %% [markdown]
# ### General Form
# ![image.png](attachment:07235bdf-a31d-4c15-b1ca-62eb05ab439f.png)

# %% [markdown]
# ## Direction Vector and Normal
# ![image.png](attachment:60017e38-db0d-4cfe-b1ce-723fdd5de734.png)

# %% [markdown]
# ## Distance between two Points
# ![image.png](attachment:bdac35ae-931a-4481-a70e-5a2f991551d0.png)
#
# ### Example
# ![image.png](attachment:651fec27-95a6-451a-aef1-1f7c1d0740c7.png)

# %% [markdown]
# ## Distance from point to Line
#
# ![image.png](attachment:76a50d9f-1498-4b40-a84e-62da6e4e159b.png)

# %% [markdown]
# ## Distance between two parallel lines
#
# ![image.png](attachment:7487de65-c38d-4304-8bed-eeba99dfe7c7.png)

# %% [markdown]
# ## The Law of Sin
# ![image.png](attachment:f2fffa7a-156e-4236-86ff-037968ec1a92.png)

# %% [markdown]
# ## The Law of Cosines
# ![image.png](attachment:a3a953b3-b296-422e-ae6f-591ad1f32463.png)
