# %% [markdown]
# # Transpose and Permutation
# ## What's Permutation Matrix
# ![image.png](attachment:d77d945d-30c4-4677-8cde-4160c0966099.png)

# %% [markdown]
# ## Why we need permutation
# ![image.png](attachment:2c7a6068-728e-4ee3-a686-ef7a31d33f34.png)

# %% [markdown]
# ## Symmetric matrix
# ![image.png](attachment:55ce053a-8fdb-437f-9047-3d3bb8f58399.png)

# %% [markdown]
# ### How can we get a symmetric matrix from any matrix
# ![image.png](attachment:17e050fb-7ea1-4fc9-b888-7b133b426402.png)

# %% [markdown]
# ### Why $R^T * R$ is always symetric?
# ![image.png](attachment:9b5f4f42-dc60-4619-a8a7-6b3f02c73295.png)
