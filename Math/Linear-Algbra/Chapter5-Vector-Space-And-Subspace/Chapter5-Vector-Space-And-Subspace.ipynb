# %% [markdown]
# # Vector Space and Subspace

# %% [markdown]
# ## What's a space
# ![image.png](attachment:33146192-91ff-4628-97a7-be296a54d83e.png)

# %% [markdown]
# ## What's Subspace
# ![image.png](attachment:9eb44aa4-5f13-4f99-8982-7d391d1ca2f7.png)

# %% [markdown]
# ## How to construct a subspace from a matrix
# ![image.png](attachment:0a1b3cbd-855f-4429-aed4-60c7951857f5.png)

# %% [markdown]
# ## Column space of matrix
# ### Definiton
# ![image.png](attachment:56b412df-e579-461e-bfc7-3d02bfbed7a5.png)
# ![image.png](attachment:ae007efc-da2c-4c5d-b361-ae466989de43.png)

# %% [markdown]
# ### Does $Ax=b$ always have a solution for every b?
#
# ![image.png](attachment:138d1d36-7aaa-4379-b1c1-7288d985437e.png)

# %% [markdown]
# ## Null space of matrix
# ### Definition
# ![image.png](attachment:b7c403c9-4bc2-445c-a43c-3e260a8ca70d.png)

# %% [markdown]
# ### Why the solution of $Ax=0$ forms a subspace?
# ![image.png](attachment:5ee40db1-95f4-4f44-9691-cbbe2037275e.png)
