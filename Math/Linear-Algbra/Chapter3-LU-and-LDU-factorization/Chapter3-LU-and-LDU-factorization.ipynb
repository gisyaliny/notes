# %% [markdown]
# # $LU and LDU factorization$
# ## Product of elimination matrices
# ![image.png](attachment:37f59a7c-37cb-41c1-a6d1-3a8357c99693.png)

# %% [markdown]
# ## Decompose Matrices
# ### $LU$ factorization
#
# ![image.png](attachment:d5d5205a-3fb8-4212-af92-8d9aea2c3e33.png)

# %% [markdown]
# ### $LU$ factorization for $3*3$ matrix
# ![image.png](attachment:7d4e52c5-86c4-46ed-b5da-d62383392bff.png)

# %% [markdown]
# ### $LDU$ factorization
# ![image.png](attachment:84248276-e6ae-4619-91d9-75d2283c65b9.png)

# %% [markdown]
# ### (Personal Question) Why we want $LU$ decomposition
